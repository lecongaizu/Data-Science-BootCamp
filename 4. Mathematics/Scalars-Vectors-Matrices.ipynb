# %%
import numpy as np

# %%
vector =  np.array([5,-2,4])
vector
# Out:
# array([ 5, -2,  4])

# %%
matrix = np.array([[5, -2,  4], [5, -2,  4]])
matrix
# Out:
# array([[ 5, -2,  4],
#        [ 5, -2,  4]])
